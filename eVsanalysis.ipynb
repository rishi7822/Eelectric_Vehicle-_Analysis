# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Electric_Vehicle_Population_Data.csv', encoding='latin-1')

# %%
df.head()
# Out:
#    VIN (1-10)    County       City State  Postal Code  Model Year       Make  \
# 0  JTMAB3FV3P    Kitsap    Seabeck    WA        98380        2023     TOYOTA
# 1  1N4AZ1CP6J    Kitsap  Bremerton    WA        98312        2018     NISSAN
# 2  5YJ3E1EA4L      King    Seattle    WA        98101        2020      TESLA
# 3  1N4AZ0CP8E      King    Seattle    WA        98125        2014     NISSAN
# 4  1G1FX6S00H  Thurston       Yelm    WA        98597        2017  CHEVROLET
#
#         Model                   Electric Vehicle Type  \
# 0  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 1        LEAF          Battery Electric Vehicle (BEV)
# 2     MODEL 3          Battery Electric Vehicle (BEV)
# 3        LEAF          Battery Electric Vehicle (BEV)
# 4     BOLT EV          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible              42
# ...

# %%
df.shape
# Out:
# (8645, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8645 entries, 0 to 8644
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   VIN (1-10)                                         8645 non-null   object
#  1   County                                             8645 non-null   object
#  2   City                                               8645 non-null   object
#  3   State                                              8645 non-null   object
#  4   Postal Code                                        8645 non-null   int64
#  5   Model Year                                         8645 non-null   int64
#  6   Make                                               8645 non-null   object
#  7   Model                                              8645 non-null   object
#  8   Electric Vehicle Type                              8645 non-null   object
# ...

# %%
df.describe()
# Out:
#         Postal Code   Model Year  Electric Range      Base MSRP  \
# count   8645.000000  8645.000000     8645.000000    8645.000000
# mean   98178.265124  2020.941932       55.096819     886.681319
# std      217.693931     2.968305       89.979547    7413.020149
# min    98001.000000  2008.000000        0.000000       0.000000
# 25%    98033.000000  2019.000000        0.000000       0.000000
# 50%    98108.000000  2022.000000        0.000000       0.000000
# 75%    98188.000000  2023.000000       72.000000       0.000000
# max    99324.000000  2025.000000      337.000000  110950.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count           8645.000000    8.645000e+03       8.644000e+03
# mean              32.922614    2.271939e+08       5.303369e+10
# std               14.597695    7.441487e+07       1.187108e+07
# min                1.000000    4.291730e+05       5.300796e+10
# 25%               21.000000    1.922945e+08       5.303301e+10
# ...

# %%
df.tail(10)
# Out:
#       VIN (1-10)    County          City State  Postal Code  Model Year  \
# 8635  7SAYGDEDXP    Island    Oak Harbor    WA        98277        2023
# 8636  5YJ3E1EA0K      King       Redmond    WA        98052        2019
# 8637  1N4AZ1CP6L    Kitsap     Bremerton    WA        98310        2020
# 8638  1C4RJXP60R    Kitsap  Port Orchard    WA        98367        2024
# 8639  7SAYGDEE5R      King      Bellevue    WA        98005        2024
# 8640  5YJ3E1EBXN      King      Bellevue    WA        98004        2022
# 8641  5YJ3E1EA7M   Clallam        Sequim    WA        98382        2021
# 8642  KNDC3DLC8P  Thurston     Rochester    WA        98579        2023
# 8643  KM8KNDAF8P    Kitsap        Olalla    WA        98359        2023
# 8644  1N4AZ0CP1E      King       Seattle    WA        98115        2014
#
#          Make     Model                   Electric Vehicle Type  \
# 8635    TESLA   MODEL Y          Battery Electric Vehicle (BEV)
# ...

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# Legislative District                                 0
# DOL Vehicle ID                                       0
# Vehicle Location                                     0
# Electric Utility                                     1
# 2020 Census Tract                                    1
# dtype: int64

# %%
df.dropna()
# Out:
#       VIN (1-10)    County       City State  Postal Code  Model Year  \
# 0     JTMAB3FV3P    Kitsap    Seabeck    WA        98380        2023
# 1     1N4AZ1CP6J    Kitsap  Bremerton    WA        98312        2018
# 2     5YJ3E1EA4L      King    Seattle    WA        98101        2020
# 3     1N4AZ0CP8E      King    Seattle    WA        98125        2014
# 4     1G1FX6S00H  Thurston       Yelm    WA        98597        2017
# ...          ...       ...        ...   ...          ...         ...
# 8639  7SAYGDEE5R      King   Bellevue    WA        98005        2024
# 8640  5YJ3E1EBXN      King   Bellevue    WA        98004        2022
# 8641  5YJ3E1EA7M   Clallam     Sequim    WA        98382        2021
# 8642  KNDC3DLC8P  Thurston  Rochester    WA        98579        2023
# 8643  KM8KNDAF8P    Kitsap     Olalla    WA        98359        2023
#
#            Make       Model                   Electric Vehicle Type  \
# 0        TOYOTA  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# ...

# %%
sns.set(style= 'whitegrid')

plt.figure(figsize=(12, 6))
ev_adoption_by_year = df['Model Year'].value_counts().sort_index()
sns.barplot(x=ev_adoption_by_year.index, y=ev_adoption_by_year.values, palette="viridis")
plt.title('EV Adoption Over Time')
plt.xlabel('Model Year')
plt.ylabel('Number of Vehicles Registered')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-22-18245988d4ef>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=ev_adoption_by_year.index, y=ev_adoption_by_year.values, palette="viridis")

# %%
numerical_summary = df.describe()

# Display
print(numerical_summary)
# Out:
#         Postal Code   Model Year  Electric Range      Base MSRP  \
# count   8645.000000  8645.000000     8645.000000    8645.000000
# mean   98178.265124  2020.941932       55.096819     886.681319
# std      217.693931     2.968305       89.979547    7413.020149
# min    98001.000000  2008.000000        0.000000       0.000000
# 25%    98033.000000  2019.000000        0.000000       0.000000
# 50%    98108.000000  2022.000000        0.000000       0.000000
# 75%    98188.000000  2023.000000       72.000000       0.000000
# max    99324.000000  2025.000000      337.000000  110950.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count           8645.000000    8.645000e+03       8.644000e+03
# mean              32.922614    2.271939e+08       5.303369e+10
# std               14.597695    7.441487e+07       1.187108e+07
# min                1.000000    4.291730e+05       5.300796e+10
# 25%               21.000000    1.922945e+08       5.303301e+10
# ...

# %%
ev_county_distribution = df['County'].value_counts()
top_counties = ev_county_distribution.head(3).index

# %%
top_counties_data = df[df['County'].isin(top_counties)]

# %%
ev_city_distribution_top_counties = top_counties_data.groupby(['County', 'City']).size().sort_values(ascending=False).reset_index(name='Number of Vehicles')

# %%
top_cities = ev_city_distribution_top_counties.head(10)

# %%
plt.figure(figsize=(12, 8))
sns.barplot(x='Number of Vehicles', y='City', hue='County', data=top_cities, palette="magma")
plt.title('Top Cities in Top Counties by EV Registrations')
plt.xlabel('Number of Vehicles Registered')
plt.ylabel('City')
plt.legend(title='County')
plt.tight_layout()
plt.show()

# %%
ev_type_distribution = df['Electric Vehicle Type'].value_counts()

plt.figure(figsize=(10, 6))
sns.barplot(x=ev_type_distribution.values, y=ev_type_distribution.index, palette="rocket")
plt.title('Distribution of Electric Vehicle Types')
plt.xlabel('Number of Vehicles Registered')
plt.ylabel('Electric Vehicle Type')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-30-967cfbe6615f>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=ev_type_distribution.values, y=ev_type_distribution.index, palette="rocket")

# %%
ev_make_distribution = df['Make'].value_counts().head(10)  # Limiting to top 10 for clarity

plt.figure(figsize=(12, 6))
sns.barplot(x=ev_make_distribution.values, y=ev_make_distribution.index, palette="cubehelix")
plt.title('Top 10 Popular EV Makes')
plt.xlabel('Number of Vehicles Registered')
plt.ylabel('Make')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-32-bd1b3641dd4e>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=ev_make_distribution.values, y=ev_make_distribution.index, palette="cubehelix")

# %%
# Assuming 'df' is your DataFrame and contains columns 'Make' and 'Model'

# Get the top 3 makes
top_3_makes = df['Make'].value_counts().head(3).index

# Filter data for the top 3 makes
df_top_makes = df[df['Make'].isin(top_3_makes)]

# Get the model distribution for the top makes
ev_model_distribution_top_makes = df_top_makes.groupby(['Make', 'Model'])['Model'].count().reset_index(name='Number of Vehicles')

# Now you can proceed with your visualization:
# visualizing the top 10 models across these manufacturers for clarity
top_models = ev_model_distribution_top_makes.head(10)

plt.figure(figsize=(12, 8))
sns.barplot(x='Number of Vehicles', y='Model', hue='Make', data=top_models, palette="viridis")
plt.title('Top Models in Top 3 Makes by EV Registrations')
plt.xlabel('Number of Vehicles Registered')
plt.ylabel('Model')
plt.legend(title='Make', loc='center right')
plt.tight_layout()
plt.show()

# %%
# analyzing the distribution of electric range
plt.figure(figsize=(12, 6))
sns.histplot(df['Electric Range'], bins=30, kde=True, color='royalblue')
plt.title('Distribution of Electric Vehicle Ranges')
plt.xlabel('Electric Range (miles)')
plt.ylabel('Number of Vehicles')
plt.axvline(df['Electric Range'].mean(), color='red', linestyle='--', label=f'Mean Range: {df["Electric Range"].mean():.2f} miles')
plt.legend()
plt.show()

# %%
# calculating the average electric range by model year
average_range_by_year = df.groupby('Model Year')['Electric Range'].mean().reset_index()

plt.figure(figsize=(12, 6))
sns.lineplot(x='Model Year', y='Electric Range', data=average_range_by_year, marker='o', color='green')
plt.title('Average Electric Range by Model Year')
plt.xlabel('Model Year')
plt.ylabel('Average Electric Range (miles)')
plt.grid(True)
plt.show()

# %%
average_range_by_model = df_top_makes.groupby(['Make', 'Model'])['Electric Range'].mean().sort_values(ascending=False).reset_index()

# the top 10 models with the highest average electric range
top_range_models = average_range_by_model.head(10)

plt.figure(figsize=(12, 8))
barplot = sns.barplot(x='Electric Range', y='Model', hue='Make', data=top_range_models, palette="cool")
plt.title('Top 10 Models by Average Electric Range in Top Makes')
plt.xlabel('Average Electric Range (miles)')
plt.ylabel('Model')
plt.legend(title='Make', loc='center right')
plt.show()

# %%
ev_registration_counts = df['Model Year'].value_counts().sort_index()
ev_registration_counts
# Out:
# Model Year
# 2008       3
# 2010       1
# 2011      32
# 2012      54
# 2013     188
# 2014     137
# 2015     189
# 2016     246
# 2017     361
# 2018     622
# 2019     476
# 2020     543
# 2021     829
# 2022    1144
# 2023    2635
# 2024    1168
# 2025      17
# Name: count, dtype: int64

# %%
from scipy.optimize import curve_fit
import numpy as np

# filter the dataset to include years with complete data, assuming 2023 is the last complete year
filtered_years = ev_registration_counts[ev_registration_counts.index <= 2023]

# define a function for exponential growth to fit the data
def exp_growth(x, a, b):
    return a * np.exp(b * x)

# prepare the data for curve fitting
x_data = filtered_years.index - filtered_years.index.min()
y_data = filtered_years.values

# fit the data to the exponential growth function
params, covariance = curve_fit(exp_growth, x_data, y_data)

# use the fitted function to forecast the number of EVs for 2024 and the next five years
forecast_years = np.arange(2024, 2024 + 6) - filtered_years.index.min()
forecasted_values = exp_growth(forecast_years, *params)

# create a dictionary to display the forecasted values for easier interpretation
forecasted_evs = dict(zip(forecast_years + filtered_years.index.min(), forecasted_values))

print(forecasted_evs)
# Out:
# {2024: 3717.6548559394246, 2025: 5798.757018134464, 2026: 9044.837204734744, 2027: 14108.037257693706, 2028: 22005.560825382545, 2029: 34324.030933185466}

# %%
# prepare data for plotting
years = np.arange(filtered_years.index.min(), 2029 + 1)
actual_years = filtered_years.index
forecast_years_full = np.arange(2024, 2029 + 1)

# actual and forecasted values
actual_values = filtered_years.values
forecasted_values_full = [forecasted_evs[year] for year in forecast_years_full]

plt.figure(figsize=(12, 8))
plt.plot(actual_years, actual_values, 'bo-', label='Actual Registrations')
plt.plot(forecast_years_full, forecasted_values_full, 'ro--', label='Forecasted Registrations')

plt.title('Current & Estimated EV Market')
plt.xlabel('Year')
plt.ylabel('Number of EV Registrations')
plt.legend()
plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Base MSRP', y='Electric Range', hue='Electric Vehicle Type', data=df, palette='coolwarm')
plt.title('Electric Range vs Base MSRP by Vehicle Type')
plt.xlabel('Base MSRP ($)')
plt.ylabel('Electric Range (Miles)')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Electric Vehicle Type', y='Electric Range', data=df, palette='Set2')
plt.title('Electric Vehicle Range by Type')
plt.xlabel('Electric Vehicle Type')
plt.ylabel('Electric Range (Miles)')
plt.show()
# Out:
# <ipython-input-44-edf551055f16>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Electric Vehicle Type', y='Electric Range', data=df, palette='Set2')

# %%
# Assuming 'Model Year' is the column containing the vehicle's model year
df['EV_Age'] = 2023 - df['Model Year']  # Calculate EV age assuming 2023 is the current year

numeric_cols = ['Electric Range', 'Base MSRP', 'EV_Age']

# Pair plot for numeric relationships
sns.pairplot(df[numeric_cols], diag_kind='kde', corner=True)
plt.title('Pairwise Relationships Between Key EV Features')
plt.show()

# Compute correlation matrix
corr_matrix = df[numeric_cols].corr()

# Plot correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap of EV Features')
plt.show()

# %%
# Count EV registrations by City
plt.figure(figsize=(14, 10))
sns.countplot(y='City', data=df[df['State'] == 'WA'], order=df['City'].value_counts().index[:15], palette='viridis')
plt.title('Electric Vehicle Registrations in Top Cities of Washington State')
plt.xlabel('Number of Vehicles')
plt.ylabel('City')
plt.show()
# Out:
# <ipython-input-47-d0aa0806183e>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y='City', data=df[df['State'] == 'WA'], order=df['City'].value_counts().index[:15], palette='viridis')

# %%
# Group by Make and Model Year, then aggregate
top_ev_makes = df.groupby(['Model Year', 'Make']).size().unstack().fillna(0)

# Top 10 EV makes
top_ev_makes = top_ev_makes[top_ev_makes.columns[:10]]

# Plot the trend of top 10 EV makes over time
plt.figure(figsize=(12, 8))
top_ev_makes.plot(kind='line', marker='o', colormap='coolwarm', linewidth=2)
plt.title('Top 10 Electric Vehicle Makes Over Time')
plt.xlabel('Year')
plt.ylabel('Number of Vehicles')
plt.legend(title='Make', loc='upper left')
plt.show()

# %%
from wordcloud import WordCloud
plt.figure(figsize=(12, 8))
wordcloud = WordCloud(background_color='white', width=800, height=400).generate(' '.join(df['Model']))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Most Popular EV Models', fontsize=20)
plt.show()
